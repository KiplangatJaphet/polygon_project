# %%
import requests
import json
import pandas as pd

# %%
api_key = "zEXBgXeV8ByiYSUeGz76YVDybISza9nV"

# %%
symbols = ["AAPL", "GOOGL", "MSFT", "AMZN", "TSLA"]

# %%
all_symbol_data = []

# %%
for symbol in symbols:
    api_url = f"https://api.massive.com/v1/open-close/{symbol}/{date}?adjusted=true&apiKey={api_key}"
    response = requests.get(api_url)
    data = response.json()
    
    data['symbol'] = symbol
    
    
    all_symbol_data.append(data)
    
if all_symbol_data:
    df = pd.DataFrame(all_symbol_data)
    df = df.rename(columns={'from': 'date'})
    print(df[['symbol', 'date', 'open', 'high', 'low', 'close', 'volume']])

# %%
import requests
import json
import pandas as pd

api_key = "zEXBgXeV8ByiYSUeGz76YVDybISza9nV"
symbols = ["AAPL", "GOOGL", "MSFT", "AMZN", "TSLA"]
date = "2026-01-09"

def fetch_stock_data():
    all_symbol_data = []
    for symbol in symbols:
        api_url = f"https://api.massive.com/v1/open-close/{symbol}/{date}?adjusted=true&apiKey={api_key}"
        response = requests.get(api_url)
        data = response.json()
        
        data['symbol'] = symbol
        
        
        all_symbol_data.append(data)
    
    if all_symbol_data:
        df = pd.DataFrame(all_symbol_data)
        df = df.rename(columns={'from': 'date'})
        print(df[['symbol', 'date', 'open', 'high', 'low', 'close', 'volume']])
        
fetch_stock_data()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 26
#      23         df = df.rename(columns={'from': 'date'})
#      24         print(df[['symbol', 'date', 'open', 'high', 'low', 'close', 'volume']])
# ---> 26 fetch_stock_data()
#
# Cell In[49], line 24, in fetch_stock_data()
#      22 df = pd.DataFrame(all_symbol_data)
#      23 df = df.rename(columns={'from': 'date'})
# ---> 24 print(df[['symbol', 'date', 'open', 'high', 'low', 'close', 'volume']])
#
# File ~/mainenv/lib/python3.12/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/mainenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/mainenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['date', 'open', 'high', 'low', 'close', 'volume'] not in index"
